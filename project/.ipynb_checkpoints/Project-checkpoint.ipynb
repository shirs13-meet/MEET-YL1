# %%
import csv

i = open('colleges.csv', 'rb')
reader = csv.reader(i)
sat = []
grad = []
rownum = 0
for row in reader:
    if rownum == 0:
        header = row
        rownum = rownum + 1
    else:
        a = row[0]
        a = a.split()
        b = a[-6:]
        c = map(int, b)
        university.extend(c)
        print c
        sat.append(c[0])
        grad.append(c[5])

print sat
print grad
# Out:
# [1315, 22, 26636, 85, 81, 93]
# [1310, 24, 27487, 78, 93, 88]
# [1336, 28, 23772, 86, 90, 93]
# [1300, 24, 25703, 78, 95, 90]
# [1250, 49, 27879, 76, 91, 86]
# [1320, 33, 26668, 79, 98, 80]
# [1290, 35, 19948, 73, 87, 91]
# [1255, 25, 24718, 65, 89, 92]
# [1195, 57, 25271, 65, 90, 87]
# [1230, 36, 17721, 77, 94, 89]
# [1287, 43, 20179, 53, 90, 84]
# [1300, 40, 19504, 75, 82, 80]
# [1260, 36, 20377, 68, 94, 74]
# [1247, 54, 23591, 64, 98, 77]
# [1234, 29, 17998, 61, 89, 78]
# [1244, 67, 22301, 65, 79, 73]
# [1200, 61, 23358, 47, 83, 83]
# [1200, 46, 18872, 52, 75, 84]
# [1215, 38, 20722, 51, 86, 85]
# [1240, 36, 17554, 58, 81, 88]
# [1285, 35, 19418, 71, 91, 87]
# [1258, 38, 17520, 61, 78, 85]
# [1255, 56, 18847, 70, 81, 84]
# [1170, 49, 20192, 54, 93, 72]
# [1220, 53, 17653, 69, 98, 80]
# [1370, 18, 46918, 90, 99, 90]
# [1370, 18, 61921, 92, 96, 88]
# [1350, 19, 52468, 90, 97, 93]
# [1340, 17, 48123, 89, 99, 93]
# [1400, 31, 102262, 98, 98, 75]
# [1357, 30, 56766, 95, 98, 86]
# ...

# %%
from pylab import *

scatter(sat, grad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-0183a6fd6606> in <module>()
#       1 from pylab import *
#       2
# ----> 3 scatter(sat, grad)
#
# NameError: name 'grad' is not defined

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title('Relationship between students SAT scores and the percentage of graduates from the University')
ax.set_xlabel('Students SAT Scores')
ax.set_ylabel('% of students at the Uni who graduate')
ax.scatter(sat, grad)
fig.savefig("colleges.png")
